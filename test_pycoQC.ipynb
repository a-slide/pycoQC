# %% [markdown]
# # TEST pycoQC package
# ** This notebook contains tests for all functions contained in pycoQC package **

# %%
# Jupyter specific imports
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Pyplot/matplotlib imports and setting
import pylab as pl
# %pylab inline
pl.rcParams['figure.figsize'] = 20, 7
pl.rcParams['font.family'] = 'sans-serif'
pl.rcParams['font.sans-serif'] = ['DejaVu Sans']
pl.style.use('ggplot')

# Import all the functions from pycoQC
from pycoQC import pycoQC
# Out:
# <style>.container { width:100% !important; }</style>
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## pycoQC __init__

# %%
help(pycoQC.__init__)
# Out:
# Help on method __init__ in module pycoQC:
#
# __init__(self, seq_summary_file, runid=None, verbose=False) unbound pycoQC.pycoQC method
#     Parse Albacore sequencing_summary.txt file and cleanup the data
#     * seq_summary_file
#         Path to the sequencing_summary.txt generated by Albacore
#     * runid
#         If you want a specific runid to be analysed. Usually there are 2 runids per minion experiment, the mux run and the sequencing
#         run. By default it will analyse the runid with the most reads, ie the sequencing run. [Default: None]
#     * verbose
#         print additional informations. [Default: False]

# %%
p = pycoQC("./test_data/sequencing_summary.txt")

# %%
p = pycoQC("./test_data/sequencing_summary.txt", verbose=True)
# Out:
# Runid found in the datasets
# Run_ID                                     Count
# ad3de3b63de71c4c6d5ea4470a82782cf51210d9  126724
# 7082b6727942b3939a023beaf03ef24cec1722e5    1013
# Selecting Run_ID ad3de3b63de71c4c6d5ea4470a82782cf51210d9
# Dataframe head
#                                                                                filename  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e128  Dell_OptiPlex_7040_20170418_FNFAF04116_MN19173...
# 472aba57-197e-4d33-9ea5-b37345b17faa  Dell_OptiPlex_7040_20170418_FNFAF04116_MN19173...
# 666705e8-dcdb-4731-b291-d3109c480c32  Dell_OptiPlex_7040_20170418_FNFAF04116_MN19173...
# 743e1e8f-214d-4669-afab-0cd3bb4d4876  Dell_OptiPlex_7040_20170418_FNFAF04116_MN19173...
# 8361b3fd-c772-4fd7-b9ae-49558341189c  Dell_OptiPlex_7040_20170418_FNFAF04116_MN19173...
#
#                                                                         run_id  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e128  ad3de3b63de71c4c6d5ea4470a82782cf51210d9
# 472aba57-197e-4d33-9ea5-b37345b17faa  ad3de3b63de71c4c6d5ea4470a82782cf51210d9
# 666705e8-dcdb-4731-b291-d3109c480c32  ad3de3b63de71c4c6d5ea4470a82782cf51210d9
# 743e1e8f-214d-4669-afab-0cd3bb4d4876  ad3de3b63de71c4c6d5ea4470a82782cf51210d9
# 8361b3fd-c772-4fd7-b9ae-49558341189c  ad3de3b63de71c4c6d5ea4470a82782cf51210d9
#
#                                       channel  start_time  duration  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e128      110  3315.66450   4.20625
# 472aba57-197e-4d33-9ea5-b37345b17faa      103  3721.13375   3.94175
# 666705e8-dcdb-4731-b291-d3109c480c32      102  4573.79600   7.03775
# 743e1e8f-214d-4669-afab-0cd3bb4d4876      109  3767.45425   1.03725
# 8361b3fd-c772-4fd7-b9ae-49558341189c      103  4517.39050   1.54200
#
#                                       num_events  template_start  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e128        3316         0.04125
# 472aba57-197e-4d33-9ea5-b37345b17faa        3086         0.11350
# 666705e8-dcdb-4731-b291-d3109c480c32        5588         0.03725
# 743e1e8f-214d-4669-afab-0cd3bb4d4876         806         0.04900
# 8361b3fd-c772-4fd7-b9ae-49558341189c         946         0.33450
#
#                                       num_events_template  template_duration  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e128                 3316            4.16500
# 472aba57-197e-4d33-9ea5-b37345b17faa                 3086            3.82825
# 666705e8-dcdb-4731-b291-d3109c480c32                 5588            7.00050
# 743e1e8f-214d-4669-afab-0cd3bb4d4876                  806            0.98825
# 8361b3fd-c772-4fd7-b9ae-49558341189c                  946            1.20750
#
#                                       num_called_template  \
# read_id
# 43bb3455-6579-4c53-a9ae-56e23777e
# 3938e8cf-8076-48ad-a2b5-5f0ce6d5863c                 8.739
#
#                                       strand_score_template
# read_id
# 6b435c57-ec5e-47b8-9d4f-e026507a4504                -0.0009
# 134a4929-394a-4619-8a70-cf89b643dd43                -0.0010
# e6a100f7-0f04-4d23-a72c-b56b9871f383                -0.0009
# 16c8ede8-565a-4cd0-8406-e463a06ddbcd                -0.0008
# 3938e8cf-8076-48ad-a2b5-5f0ce6d5863c                -0.0009

# %% [markdown]
# ## channels_activity

# %%
help(pycoQC.channels_activity)
# Out:
# Help on method channels_activity in module pycoQC:
#
# channels_activity(self, level='reads', figsize=[24, 12], cmap='OrRd', alpha=1, robust=True, annot=True, fmt='d', cbar=False, **kwargs) unbound pycoQC.pycoQC method
#     Plot the activity of channels at read, base or event level. Based on Seaborn heatmap function. The layout does not represent the
#     physical layout of the flowcell, and
#     * level
#         Aggregate channel output results by "reads", "bases" or "events". [Default: "reads"]
#     * figsize
#         Size of ploting area [Default: [24,12]]
#     * cmap
#         Matplotlib colormap code to color the space [Default: "OrRd"]
#     * alpha
#         Opacity of the area from 0 to 1 [Default: 1]
#     * robust
#         if True the colormap range is computed with robust quantiles instead of the extreme values [Default: True]
#     * annot
#         If True, write the data value in each cell. [Default: True]
#     * fmt
#         String formatting code to use when adding annotations (see matplotlib documentation) [Default: "d"]
#     * cbar
#         Whether to draw a colorbar scale on the right of the graph [Default: False]
#     => Return
#         A matplotlib.axes object for further user customisation (http://matplotlib.org/api/axes_api.html)

# %%
p = pycoQC("./test_data/sequencing_summary.txt")
g = p.channels_activity(level='reads')
g = p.channels_activity(level='bases', cmap="Blues")
g = p.channels_activity(level='events', cmap="viridis", cbar=True, annot=False, figsize=[30,12], robust=False)

# Changing properties of the axis title
g.title.set_fontsize(20)
g.title.set_color("blue")
g.title.set_fontweight("bold")

# %% [markdown]
# ## mean_qual_distribution

# %%
help(pycoQC.mean_qual_distribution)
# Out:
# Help on method mean_qual_distribution in module pycoQC:
#
# mean_qual_distribution(self, figsize=[30, 7], color='orangered', alpha=0.5, normed=True, win_size=0.1, xmin=0, xmax=40, **kwargs) unbound pycoQC.pycoQC method
#     Plot the distribution of the mean read PHRED qualities
#     * figsize
#         Size of ploting area [Default:figsize=[30,7]
#     * color
#         Color of the plot. Valid matplotlib color code [Default "orangered"]
#     * alpha
#         Opacity of the area from 0 to 1 [Default: 1]
#     * normed
#         Normalised results. Frenquency rather than counts [Default True]
#     * win_size
#         Size of the bins in quality score ranging from 0 to 40 [Default 0.1]
#     * xmin, xmax
#         Lower and upper limits on x axis [Default 0, 40]
#     => Return
#         A matplotlib.axes object for further user customisation (http://matplotlib.org/api/axes_api.html)

# %%
p = pycoQC("./test_data/sequencing_summary.txt")
g = p.mean_qual_distribution()
g = p.mean_qual_distribution(figsize=[15, 7], color='red', alpha=0.5, normed=False, win_size=0.05, xmin=2, xmax=18)

# Changing size of the axis title and labels
g.title.set_fontsize(20)
g.xaxis.label.set_fontsize(18)
g.yaxis.label.set_fontsize(18)

# %% [markdown]
# ## output_over_time

# %%
help(pycoQC.output_over_time)
# Out:
# Help on method output_over_time in module pycoQC:
#
# output_over_time(self, level='reads', figsize=[30, 7], color='orangered', alpha=0.5, win_size=0.25, cumulative=False, **kwargs) unbound pycoQC.pycoQC method
#     Plot the output over the time of the experiment at read, base or event level
#     * level
#         Aggregate channel output results by "reads", "bases" or "events" [Default: "reads"]
#     * figsize
#         Size of ploting area [Default:figsize=[30,7]
#     * color
#         Color of the plot. Valid matplotlib color code [Default "orangered"]
#     * alpha
#         Opacity of the area from 0 to 1 [Default: 0.5]
#     * win_size
#         Size of the bins in hours [Default 0.25]
#     * cumulative
#         cumulative histogram [Default False]
#     => Return
#         A matplotlib.axes object for further user customisation (http://matplotlib.org/api/axes_api.html)

# %%
p = pycoQC("./test_data/sequencing_summary.txt")
g = p.output_over_time(level='reads')
g = p.output_over_time(level='bases', figsize=[25, 7], color='orangered', alpha=0.7, win_size=0.5, cumulative=False)
g = p.output_over_time(level='events', figsize=[20, 7], color='red', alpha=0.4, win_size=0.1, cumulative=True)

# Changing size of the axis title and labels
g.title.set_fontsize(20)
g.xaxis.label.set_fontsize(18)
g.yaxis.label.set_fontsize(18)

# %% [markdown]
# ## quality_over_time

# %%
help(pycoQC.quality_over_time)
# Out:
# Help on method quality_over_time in module pycoQC:
#
# quality_over_time(self, figsize=[30, 7], color='orangered', alpha=0.25, win_size=0.25, **kwargs) unbound pycoQC.pycoQC method
#     Plot the evolution of the mean read quality over the time of the experiment at read, base or event level
#     * figsize
#         Size of ploting area [Default:figsize=[30,7]
#     * color
#         Color of the plot. Valid matplotlib color code [Default "orangered"]
#     * alpha
#         Opacity of the area from 0 to 1 [Default: 0.25]
#     * win_size
#         Size of the bins in hours [Default 0.25]
#     => Return
#         A matplotlib.axes object for further user customisation (http://matplotlib.org/api/axes_api.html)

# %%
p = pycoQC("./test_data/sequencing_summary.txt")
g = p.quality_over_time()
g = p.quality_over_time(figsize=[20,7], color='dodgerblue', alpha=0.3, win_size=1)

# Changing size of the axis title and labels
g.title.set_fontsize(20)
g.xaxis.label.set_fontsize(18)
g.yaxis.label.set_fontsize(18)

# %% [markdown]
# ## reads_len_distribution

# %%
help(pycoQC.reads_len_distribution)
# Out:
# Help on method reads_len_distribution in module pycoQC:
#
# reads_len_distribution(self, figsize=[30, 7], color='orangered', alpha=0.5, win_size=1000, normed=False, xlog=False, ylog=False, xmin=1, xmax=None, ymin=1, ymax=None, **kwargs) unbound pycoQC.pycoQC method
#     Plot the distribution of read length in base pairs
#     * figsize
#         Size of ploting area [Default:figsize=[30,7]
#     * color
#         Color of the plot. Valid matplotlib color code [Default "orangered"]
#     * alpha
#         Opacity of the area from 0 to 1 [Default: 0.5]
#     * win_size
#         Size of the bins in base pairs [Default 1000]
#     * normed
#         Normalised results. Frenquency rather than counts [Default False]
#     * xlog, ylog
#         Use log10 scale for x and y axis [Default True, True]
#     * xmin, xmax
#         Lower and upper limits on x axis [Default 1, None]
#     * ymin, ymax
#         Lower and upper limits on y axis [Default 1, None]
#     => Return
#         A matplotlib.axes object for further user customisation (http://matplotlib.org/api/axes_api.html)

# %%
p = pycoQC("./test_data/sequencing_summary.txt")
g = p.reads_len_distribution(figsize=[30, 5])
g.set_title("Distribution of read length linear scale")
g.title.set_fontsize(20)

g = p.reads_len_distribution(figsize=[30, 5], color='dodgerblue', alpha=0.5, win_size=500, normed=False, xlog=True, ylog=True)
g.set_title("Distribution of read length log10/log10 scale")
g.title.set_fontsize(20)

g = p.reads_len_distribution(figsize=[30, 5], color='green', alpha=0.5, win_size=500, normed=False, xlog=True, ylog=False, xmin=10, xmax=100000, ymin=10, ymax=6000)
g.set_title("Distribution of read length log10/linear scale")
g.title.set_fontsize(20)

g = p.reads_len_distribution(figsize=[30, 5], color='orchid', alpha=0.5, win_size=50, normed=False, xlog=False, ylog=True, xmin=10, xmax=50000, ymin=10, ymax=None)
g.set_title("Distribution of read length linear/log10 scale")
g.title.set_fontsize(20)
